# %%
import os
import matplotlib.pyplot as plt
import tensorflow as tf

import numpy as np
import pandas as pd

import lib.Metrics as Metrics
from lib.models.IRNN_Full_Bayes import IRNN_Full_Bayes
from lib.models.IRNN import IRNN
from lib.train_functions import fit
from lib.utils import *
from lib.regional_data_builder import DataConstructor

print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
region = 'US'
n_queries = 90
n_regions = 1

for test_season in [2015, 2016, 2017, 2018]:
    batch_size = 32
    window_size = 28
    _data = DataConstructor(test_season=test_season, region = region, window_size=window_size, n_queries=n_queries, gamma=28)
    x_train, y_train, x_test, y_test, scaler = _data()

    x_train = tf.cast(x_train, tf.float32)
    y_train = tf.cast(y_train, tf.float32)
    x_test = tf.cast(x_test, tf.float32)
    y_test = tf.cast(y_test, tf.float32)

    train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
    train_dataset = train_dataset.shuffle(buffer_size=1024).batch(batch_size)

    n_op = y_test.shape[-1]

    gamma = 28
    epochs= 30
    kl_power= -2.857091693154802
    lr_power= -3.7364141761644545
    op_scale_pwr= -0.27139484469983133
    p_scale_pwr= -1.827071638197097
    q_scale_pwr= -1.2461978663286395
    rnn_units= 108
    lag = 14
    epochs= 1
    n_samples = 3
    prediction_steps = 5


    _model = IRNN(kl_power=kl_power, 
                        n_op=n_op,
                        op_scale_pwr=op_scale_pwr,
                        p_scale_pwr=p_scale_pwr,
                        q_scale_pwr=q_scale_pwr,
                        rnn_units = rnn_units, 
                        gamma=gamma,       
                        window_size=window_size, 
                        lag = lag,
                        n_samples=prediction_steps,
                        n_regions = n_regions,
                        use_bn = True
                        )

    def loss_fn(y, p_y):
        return -p_y.log_prob(y)

    optimizer = tf.optimizers.Adam(learning_rate=10**lr_power)
    
    pred = _model(x_test)

    _model.compile(optimizer=optimizer, loss=loss_fn)
    _model.fit(train_dataset, epochs =epochs)
    
    file = f'Weights/IRNN/{test_season}{region}_weights.tf'
    if os.path.exists(file):
        os.remove(file)
        
    _model.save_weights(file)
# Out:
# WARNING:tensorflow:From c:\Users\micha\miniconda3\envs\tf2_env\lib\site-packages\tensorflow_probability\python\distributions\distribution.py:342: calling MultivariateNormalDiag.__init__ (from tensorflow_probability.python.distributions.mvn_diag) with scale_identity_multiplier is deprecated and will be removed after 2020-01-01.
# Instructions for updating:
# `scale_identity_multiplier` is deprecated; please combine it into `scale_diag` directly instead.
# WARNING:tensorflow:From c:\Users\micha\miniconda3\envs\tf2_env\lib\site-packages\tensorflow_probability\python\distributions\distribution.py:342: calling _Independent.__init__ (from tensorflow_probability.python.distributions.independent) with reinterpreted_batch_ndims=None is deprecated and will be removed after 2022-03-01.
# Instructions for updating:
# Please pass an integer value for `reinterpreted_batch_ndims`. The current behavior corresponds to `reinterpreted_batch_ndims=tf.size(distribution.batch_shape_tensor()) - 1`.
# Epoch 1:   0%|          | 0/130 [00:51<?, ?batch/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 56
#      52 optimizer = tf.optimizers.Adam(learning_rate=10**lr_power)
#      54 pred = _model(x_test)
# ---> 56 _model, history = fit(_model,
#      57                     train_dataset,
#      58                     optimizer=optimizer,
#      59                     epochs = epochs,
#      60                     loss_fn = loss_fn,
#      61                     prediction_steps = prediction_steps,
#      62                     reset_pos=2000
#      63                     )
#      65 file = f'Weights/{test_season}{region}_weights.tf'
#      66 if os.path.exists(file):
#
# File c:\Users\micha\OneDrive\Documents\GitHub\Forecasting-Influenza-Using-Neural-Networks-with-Uncertainty\lib\train_functions.py:103, in fit(_model, dataset, optimizer, loss_fn, epochs, reset_pos, split_steps, prediction_steps)
#     100 kl_w = KL_annealing(steps_counter, reset_pos=reset_pos, split=0.5, lower = 0.0, upper = 1.0, type = 'cosine')
#     101 tepoch.set_description(f"Epoch {epoch+1}")
# --> 103 nll_value, kl_value = train_step(_model,
#     104                                  x_batch_train,
#     105                                  y_batch_train,
#     106                                  loss_fn,
#     107                                  optimizer,
#     108                                  kl_w = kl_w,
#     109                                  prediction_steps=prediction_steps,
#     110                                  split_steps=split_steps
#     111                                 )
#     113 nll_total += tf.reduce_mean(nll_value).numpy()
#     114 kl_total += tf.reduce_mean(kl_value).numpy()
#
# File c:\Users\micha\miniconda3\envs\tf2_env\lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_filepbk7hoxi.py:38, in outer_factory.<locals>.inner_factory.<locals>.tf__train_step(_model, x, y, loss_fn, optimizer, kl_w, prediction_steps, split_steps)
#      36     ag__.for_stmt(ag__.converted_call(ag__.ld(zip), (ag__.converted_call(ag__.ld(split_uneven), (ag__.ld(x), ag__.ld(split_steps)), None, fscope), ag__.converted_call(ag__.ld(split_uneven), (ag__.ld(y), ag__.ld(split_steps)), None, fscope)), None, fscope), None, loop_body, get_state, set_state, (), {'iterate_names': '(xn, yn)'})
#      37     nll = ag__.converted_call(ag__.ld(tf).reduce_mean, (ag__.converted_call(ag__.ld(tf).concat, (ag__.ld(nll), 0), None, fscope),), None, fscope)
# ---> 38     kl = ag__.ld(kl_w) * ag__.converted_call(ag__.ld(tf).reduce_mean, (ag__.converted_call(ag__.ld(tf).concat, ([ag__.ld(_model).layers[0].KL_rec_kernel, ag__.ld(_model).layers[0].KL_kernel, ag__.ld(_model).layers[0].KL_bias, ag__.ld(_model).layers[2].kl_penalty], 0), None, fscope),), None, fscope)
#      39     loss_value = ag__.ld(kl) + ag__.ld(nll)
#      40 grads = ag__.converted_call(ag__.ld(tape).gradient, (ag__.ld(loss_value), ag__.ld(_model).trainable_weights), None, fscope)
#
# AttributeError: in user code:
#
#     File "c:\Users\micha\OneDrive\Documents\GitHub\Forecasting-Influenza-Using-Neural-Networks-with-Uncertainty\lib\train_functions.py", line 80, in train_step  *
#         kl = kl_w*tf.reduce_mean(tf.concat([_model.layers[0].KL_rec_kernel,
#
#     AttributeError: 'GRUCell' object has no attribute 'KL_rec_kernel'

# %%
_model.compile(optimizer=optimizer, loss=loss_fn)
_model.fit(train_dataset, epochs =200)
# Out:
# Epoch 1/200
# 130/130 [==============================] - 12s 47ms/step - loss: 18.3662
# Epoch 2/200
# 130/130 [==============================] - 6s 47ms/step - loss: 8.3794
# Epoch 3/200
# 130/130 [==============================] - 6s 49ms/step - loss: 3.4883
# Epoch 4/200
# 130/130 [==============================] - 6s 49ms/step - loss: 1.0733
# Epoch 5/200
200
# 130/130 [==============================] - 6s 47ms/step - loss: -2.0082
# Epoch 111/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0121
# Epoch 112/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0178
# Epoch 113/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0205
# Epoch 114/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0216
# Epoch 115/200
# 130/130 [==============================] - 6s 47ms/step - loss: -2.0210
# Epoch 116/200
# 130/130 [==============================] - 6s 49ms/step - loss: -2.0244
# Epoch 117/200
# 130/130 [==============================] - 6s 49ms/step - loss: -2.0249
# Epoch 118/200
# 130/130 [==============================] - 6s 47ms/step - loss: -2.0247
# Epoch 119/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0274
# Epoch 120/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0288
# Epoch 121/200
# 130/130 [==============================] - 6s 46ms/step - loss: -2.0295
# Epoch 122/200
# 130/130 [==============================] - 6s 47ms/step - loss: -2.0320
# Epoch 123/200
# 130/130 [==============================] - 7s 52ms/step - loss: -2.0287
# Epoch 124/200
# 130/130 [==============================] - 6s 47ms/step - loss: -2.0319
# Epoch 125/200
# 130/130 [==============================] - 6s 47ms/step - loss: -2.0291
# Epoch 126/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0349
# Epoch 127/200
# 130/130 [==============================] - 6s 47ms/step - loss: -2.0390
# Epoch 128/200
# 130/130 [==============================] - 6s 47ms/step - loss: -2.0362
# Epoch 129/200
# 130/130 [==============================] - 6s 49ms/step - loss: -2.0382
# Epoch 130/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0335
# Epoch 131/200
# 130/130 [==============================] - 6s 47ms/step - loss: -2.0445
# Epoch 132/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0461
# Epoch 133/200
# 130/130 [==============================] - 6s 50ms/step - loss: -2.0461
# Epoch 134/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0466
# Epoch 135/200
# 130/130 [==============================] - 6s 47ms/step - loss: -2.0465
# Epoch 136/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0511
# Epoch 137/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0504
# Epoch 138/200
# 130/130 [==============================] - 6s 49ms/step - loss: -2.0487
# Epoch 139/200
# 130/130 [==============================] - 6s 47ms/step - loss: -2.0515
# Epoch 140/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0452
# Epoch 141/200
# 130/130 [==============================] - 7s 50ms/step - loss: -2.0550
# Epoch 142/200
# 130/130 [==============================] - 6s 47ms/step - loss: -2.0587
# Epoch 143/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0540
# Epoch 144/200
# 130/130 [==============================] - 6s 49ms/step - loss: -2.0578
# Epoch 145/200
# 130/130 [==============================] - 7s 51ms/step - loss: -2.0574
# Epoch 146/200
# 130/130 [==============================] - 6s 50ms/step - loss: -2.0637
# Epoch 147/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0641
# Epoch 148/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0629
# Epoch 149/200
# 130/130 [==============================] - 6s 49ms/step - loss: -2.0597
# Epoch 150/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0657
# Epoch 151/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0647
# Epoch 152/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0688
# Epoch 153/200
# 130/130 [==============================] - 6s 49ms/step - loss: -2.0635
# Epoch 154/200
# 130/130 [==============================] - 6s 47ms/step - loss: -2.0714
# Epoch 155/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0659
# Epoch 156/200
# 130/130 [==============================] - 6s 47ms/step - loss: -2.0700
# Epoch 157/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0736
# Epoch 158/200
# 130/130 [==============================] - 6s 46ms/step - loss: -2.0755
# Epoch 159/200
# 130/130 [==============================] - 6s 46ms/step - loss: -2.0741
# Epoch 160/200
# 130/130 [==============================] - 6s 49ms/step - loss: -2.0761
# Epoch 161/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0778
# Epoch 162/200
# 130/130 [==============================] - 6s 47ms/step - loss: -2.0800
# Epoch 163/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0617
# Epoch 164/200
# 130/130 [==============================] - 6s 47ms/step - loss: -2.0817
# Epoch 165/200
# 130/130 [==============================] - 7s 50ms/step - loss: -2.0832
# Epoch 166/200
# 130/130 [==============================] - 7s 51ms/step - loss: -2.0843
# Epoch 167/200
# 130/130 [==============================] - 6s 49ms/step - loss: -2.0566
# Epoch 168/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0842
# Epoch 169/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0867
# Epoch 170/200
# 130/130 [==============================] - 6s 47ms/step - loss: -2.0873
# Epoch 171/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0886
# Epoch 172/200
# 130/130 [==============================] - 6s 49ms/step - loss: -2.0884
# Epoch 173/200
# 130/130 [==============================] - 6s 49ms/step - loss: -2.0879
# Epoch 174/200
# 130/130 [==============================] - 6s 47ms/step - loss: -2.0918
# Epoch 175/200
# 130/130 [==============================] - 6s 47ms/step - loss: -2.0916
# Epoch 176/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0883
# Epoch 177/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0948
# Epoch 178/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0942
# Epoch 179/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0816
# Epoch 180/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0898
# Epoch 181/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0905
# Epoch 182/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.0991
# Epoch 183/200
# 130/130 [==============================] - 6s 49ms/step - loss: -2.0990
# Epoch 184/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.1006
# Epoch 185/200
# 130/130 [==============================] - 6s 47ms/step - loss: -2.0998
# Epoch 186/200
# 130/130 [==============================] - 6s 47ms/step - loss: -2.0942
# Epoch 187/200
# 130/130 [==============================] - 6s 47ms/step - loss: -2.1030
# Epoch 188/200
# 130/130 [==============================] - 6s 47ms/step - loss: -2.1036
# Epoch 189/200
# 130/130 [==============================] - 6s 47ms/step - loss: -2.1041
# Epoch 190/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.1045
# Epoch 191/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.1064
# Epoch 192/200
# 130/130 [==============================] - 6s 47ms/step - loss: -2.1063
# Epoch 193/200
# 130/130 [==============================] - 6s 46ms/step - loss: -2.1077
# Epoch 194/200
# 130/130 [==============================] - 6s 47ms/step - loss: -2.1084
# Epoch 195/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.1084
# Epoch 196/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.1069
# Epoch 197/200
# 130/130 [==============================] - 6s 48ms/step - loss: -2.1108
# Epoch 198/200
# 130/130 [==============================] - 6s 50ms/step - loss: -2.1112
# Epoch 199/200
# 130/130 [==============================] - 6s 47ms/step - loss: -2.1107
# Epoch 200/200
# 130/130 [==============================] - 6s 47ms/step - loss: -2.1124

# %%
pred = _model(x_test)

# %%
region = 'US'
n_queries = 90
n_regions = 1

predictions = {}
for test_season in [2015, 2016, 2017, 2018]:
    batch_size = 32
    window_size = 28
    _data = DataConstructor(test_season=test_season, region = region, window_size=window_size, n_queries=n_queries, gamma=28)
    x_train, y_train, x_test, y_test, scaler = _data()

    x_train = tf.cast(x_train, tf.float32)
    y_train = tf.cast(y_train, tf.float32)
    x_test = tf.cast(x_test, tf.float32)
    y_test = tf.cast(y_test, tf.float32)

    train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
    train_dataset = train_dataset.shuffle(buffer_size=1024).batch(batch_size)

    n_op = y_test.shape[-1]

    gamma = 28
    epochs= 30
    kl_power= -2.857091693154802
    lr_power= -3.7364141761644545
    op_scale_pwr= -0.27139484469983133
    p_scale_pwr= -1.827071638197097
    q_scale_pwr= -1.2461978663286395
    rnn_units= 108
    lag = 14

    n_samples = 3
    prediction_steps = 5
    n_regions = 49


    file = f'Weights/{test_season}{region}_weights.tf'

    loaded_model = IRNN_Full_Bayes(kl_power=kl_power, 
                            n_op=n_op,
                            op_scale_pwr=op_scale_pwr,
                            p_scale_pwr=p_scale_pwr,
                            q_scale_pwr=q_scale_pwr,
                            rnn_units = rnn_units, 
                            gamma=gamma,       
                            window_size=window_size, 
                            lag = lag,
                            n_samples=prediction_steps,
                            use_bn = True
                            )
    
    try:
        scaler = scaler[np.newaxis, np.newaxis, :]
    except:
        scaler = scaler[0]
        
    loaded_model.load_weights(file)

    y_pred = loaded_model.predict(x_test, 128, verbose=True)
    std = (y_pred[0]+y_pred[1])[..., -n_regions:] * scaler - y_pred[0][..., -n_regions:] * scaler
    mean = y_pred[0][..., -n_regions:] * scaler
    y_te = y_test[..., -n_regions:]*scaler

    predictions[test_season] = {'true':y_te,
                            'mean':mean,
                            'std':std}

skills = pd.DataFrame(index = [7,14,21,28], columns = [2015,2016,2017,2018], dtype=float)
for g in [6,13,20,27]:
    for season in [2015,2016,2017,2018]:
        pred = predictions[season]
        skills.loc[g+1, season] = np.exp(np.mean(Metrics.mb_log(pred['true'][:, g, :], pred['mean'][:, g, :], pred['std'][:, g, :]))).astype(float)
print(np.exp(np.mean(np.log(skills), 1)))
# Out:
# WARNING:tensorflow:From c:\Users\micha\miniconda3\envs\tf2_env\lib\site-packages\tensorflow_probability\python\distributions\distribution.py:345: calling MultivariateNormalDiag.__init__ (from tensorflow_probability.python.distributions.mvn_diag) with scale_identity_multiplier is deprecated and will be removed after 2020-01-01.
# Instructions for updating:
# `scale_identity_multiplier` is deprecated; please combine it into `scale_diag` directly instead.
# WARNING:tensorflow:From c:\Users\micha\miniconda3\envs\tf2_env\lib\site-packages\tensorflow_probability\python\distributions\distribution.py:345: calling Independent.__init__ (from tensorflow_probability.python.distributions.independent) with reinterpreted_batch_ndims=None is deprecated and will be removed after 2022-03-01.
# Instructions for updating:
# Please pass an integer value for `reinterpreted_batch_ndims`. The current behavior corresponds to `reinterpreted_batch_ndims=tf.size(distribution.batch_shape_tensor()) - 1`.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.data_structures has been moved to tensorflow.python.trackable.data_structures. The old module will be deleted in version 2.11.
# 7     0.708269
# 14    0.710259
# 21    0.615768
# 28    0.581985
# dtype: float64

# %%
# try:
#     scaler = scaler[np.newaxis, np.newaxis, :]
# except:
#     scaler = scaler[0]
    
y_pred = _model.predict(x_test, 128, verbose=True)
std = (y_pred[0]+y_pred[1])[..., -n_regions:] * scaler - y_pred[0][..., -n_regions:] * scaler
mean = y_pred[0][..., -n_regions:] * scaler
y_te = y_test[..., -n_regions:]*scaler
# Out:
# 100%|██████████| 128/128 [01:44<00:00,  1.22it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 11
#       8 mean = y_pred[0][..., -n_regions:] * scaler
#       9 y_te = y_test[..., -n_regions:]*scaler
# ---> 11 predictions[test_season] = {'true':y_te,
#      12                         'mean':mean,
#      13                         'std':std}
#
# NameError: name 'predictions' is not defined

# %%
predictions = {}
predictions[test_season] = {'true':y_te,
                        'mean':mean,
                        'std':std}

# %%
df = pd.DataFrame(columns = [2015,2016,2017,2018], index = [7,14,21,28])
for test_season in [2015,2016,2017,2018]:
    pred = predictions[test_season]
    for num, g in zip([1,2,3,4], [7,14,21,28]):
        nll = Metrics.nll(pred['true'][:, g-1, -1], pred['mean'][:, g-1, -1], pred['std'][:, g-1, -1])
        df.loc[g, test_season] = nll
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 3
#       1 df = pd.DataFrame(columns = [2015,2016,2017,2018], index = [7,14,21,28])
#       2 for test_season in [2015,2016,2017,2018]:
# ----> 3     pred = predictions[test_season]
#       4     for num, g in zip([1,2,3,4], [7,14,21,28]):
#       5         nll = Metrics.nll(pred['true'][:, g-1, -1], pred['mean'][:, g-1, -1], pred['std'][:, g-1, -1])
#
# KeyError: 2016

# %%
for test_season in [2015,2016,2017,2018]:
    pred = predictions[test_season]
    for num, g in zip([1,2,3,4], [6,13,20,27]):
        plt.subplot(2,2,num)
        plt.plot(pred['true'][:, g, -1], color='black')
        plt.plot(pred['mean'][:, g, -1], color='red')
        plt.fill_between(np.arange(pred['true'].shape[0]), (pred['mean']-pred['std'])[:, g, -1], (pred['mean']+pred['std'])[:, g, -1], color='red', linewidth = 0, alpha = 0.3)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 2
#       1 for test_season in [2015,2016,2017,2018]:
# ----> 2     pred = predictions[test_season]
#       3     for num, g in zip([1,2,3,4], [6,13,20,27]):
#       4         plt.subplot(2,2,num)
#
# KeyError: 2016

# %%
df
# Out:
#         2015 2016 2017 2018
# 7  -0.253974  NaN  NaN  NaN
# 14  0.005461  NaN  NaN  NaN
# 21  0.412974  NaN  NaN  NaN
# 28  0.854877  NaN  NaN  NaN
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
